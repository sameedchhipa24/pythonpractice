# %%
# !pip install lxml
# Out:
# ^C
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB 1.3 MB/s eta 0:00:03
#    ---------------------------------------- 0.0/3.8 MB 1.3 MB/s eta 0:00:03
#    ---------------------------------------- 0.0/3.8 MB 281.8 kB/s eta 0:00:14
#    - -------------------------------------- 0.1/3.8 MB 599.1 kB/s eta 0:00:07
#    - -------------------------------------- 0.1/3.8 MB 599.1 kB/s eta 0:00:07
#    - -------------------------------------- 0.1/3.8 MB 599.1 kB/s eta 0:00:07
#    - -------------------------------------- 0.1/3.8 MB 599.1 kB/s eta 0:00:07
#    - -------------------------------------- 0.1/3.8 MB 599.1 kB/s eta 0:00:07
#    - -------------------------------------- 0.2/3.8 MB 327.7 kB/s eta 0:00:11
#    - -------------------------------------- 0.2/3.8 MB 327.7 kB/s eta 0:00:11
#    -- ------------------------------------- 0.2/3.8 MB 353.1 kB/s eta 0:00:11
# ...

# %%
# !pip install pandas
import pandas as pd

tables = pd.read_html('https://www.w3schools.com/python/python_ref_functions.asp')
for table in tables[0]:
    print(table)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\Python1\Assigment\BuiltinFunction.ipynb Cell 3 line 4
#       <a href='vscode-notebook-cell:/e%3A/Python1/Assigment/BuiltinFunction.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # !pip install pandas
#       <a href='vscode-notebook-cell:/e%3A/Python1/Assigment/BuiltinFunction.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/e%3A/Python1/Assigment/BuiltinFunction.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> tables = pd.read_html('https://www.w3schools.com/python/python_ref_functions.asp')
#       <a href='vscode-notebook-cell:/e%3A/Python1/Assigment/BuiltinFunction.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> for table in tables[0]:
#       <a href='vscode-notebook-cell:/e%3A/Python1/Assigment/BuiltinFunction.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a>     print(table)
#
# ...
